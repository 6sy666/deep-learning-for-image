# %% [markdown]
# <a href="https://colab.research.google.com/github/6sy666/deep-learning-for-image/blob/main/VGG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/chengyangfu/pytorch-vgg-cifar10.git
# Out:
# Cloning into 'pytorch-vgg-cifar10'...
# remote: Enumerating objects: 67, done.
# remote: Total 67 (delta 0), reused 0 (delta 0), pack-reused 67
# Unpacking objects: 100% (67/67), done.

# %%
# !cd pytorch-vgg-cifar10/ && wget http://www.cs.unc.edu/~cyfu/cifar10/model_best.pth.tar
# Out:
# --2022-10-28 04:39:16--  http://www.cs.unc.edu/~cyfu/cifar10/model_best.pth.tar
# Resolving www.cs.unc.edu (www.cs.unc.edu)... 152.19.160.128
# Connecting to www.cs.unc.edu (www.cs.unc.edu)|152.19.160.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 82223980 (78M) [application/x-tar]
# Saving to: ‘model_best.pth.tar’
#
# model_best.pth.tar  100%[===================>]  78.41M  26.6MB/s    in 2.9s
#
# 2022-10-28 04:39:20 (26.6 MB/s) - ‘model_best.pth.tar’ saved [82223980/82223980]

# %%
# !cd pytorch-vgg-cifar10/ && python main.py --resume=./model_best.pth.tar -e
# Out:
# => loading checkpoint './model_best.pth.tar'
# => loaded checkpoint 'True' (epoch 233)
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test: [0/79]	Time 2.357 (2.357)	Loss 0.2798 (0.2798)	Prec@1 95.312 (95.312)
# Test: [20/79]	Time 0.020 (0.133)	Loss 0.4300 (0.4210)	Prec@1 91.406 (92.448)
# Test: [40/79]	Time 0.026 (0.082)	Loss 0.3954 (0.4370)	Prec@1 92.188 (92.264)
# Test: [60/79]	Time 0.017 (0.063)	Loss 0.4454 (0.4327)	Prec@1 92.969 (92.367)
#  * Prec@1 92.430

# %%
! cd pytorch-vgg-cifar10/ && ./run.sh

# %%
! cd pytorch-vgg-cifar10/ && python main.py  --arch=$vgg11  --save-dir=save_$vgg11 |& tee -a log_$vgg11
# Out:
# usage: main.py [-h] [--arch ARCH] [-j N] [--epochs N] [--start-epoch N] [-b N]
#                [--lr LR] [--momentum M] [--weight-decay W] [--print-freq N]
#                [--resume PATH] [-e] [--pretrained] [--half] [--cpu]
#                [--save-dir SAVE_DIR]
# main.py: error: argument --arch/-a: invalid choice: '' (choose from 'vgg11', 'vgg11_bn', 'vgg13', 'vgg13_bn', 'vgg16', 'vgg16_bn', 'vgg19', 'vgg19_bn')

# %%
! cd pytorch-vgg-cifar10/ && ./run.sh
# Out:
# python main.py  --arch=vgg11  --save-dir=save_vgg11 |& tee -a log_vgg11
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: [0][0/391]	Time 2.946 (2.946)	Data 0.240 (0.240)	Loss 2.3038 (2.3038)	Prec@1 7.031 (7.031)
# Epoch: [0][20/391]	Time 0.025 (0.170)	Data 0.000 (0.015)	Loss 2.3039 (2.3033)	Prec@1 9.375 (9.710)
# Epoch: [0][40/391]	Time 0.031 (0.110)	Data 0.005 (0.018)	Loss 2.2768 (2.2968)	Prec@1 10.156 (10.747)
# Epoch: [0][60/391]	Time 0.027 (0.087)	Data 0.004 (0.015)	Loss 2.1806 (2.2721)	Prec@1 17.188 (12.500)
# ...
